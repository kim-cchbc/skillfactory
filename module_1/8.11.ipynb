# %%
import pandas as pd
sample = pd.read_csv('/Users/maryanapopova/Documents/GitHub/skillfactory/module_1/sample.xls')
sample
# Out:
#             Name         City  Age Profession
# 0         Иванов       Москва   25     Клинер
# 1            NaN    Волгоград   31   Менеджер
# 2         Иванов       Москва   25     Клинер
# 3        sidorov  Владивосток   43   Менеджер
# 4        _______        Курск   50   Водитель
# 5       Кузнецов         Сочи   19    Рабочий
# 6          Сажин       Сургут   29    Рабочий
# 7   Котлеревский   Йошкар-Ола   32    Рабочий
# 8     Завалишина    Чебоксары   36   Менеджер
# 9         Левина          NaN   55    Рабочий
# 10          Фикс         Рига   42    Рабочий

# %%
sample2 = sample
sample2['Age'] = sample.Age.apply(lambda x:x+1)
sample2
# Out:
#             Name         City  Age Profession
# 0         Иванов       Москва   26     Клинер
# 1            NaN    Волгоград   32   Менеджер
# 2         Иванов       Москва   26     Клинер
# 3        sidorov  Владивосток   44   Менеджер
# 4        _______        Курск   51   Водитель
# 5       Кузнецов         Сочи   20    Рабочий
# 6          Сажин       Сургут   30    Рабочий
# 7   Котлеревский   Йошкар-Ола   33    Рабочий
# 8     Завалишина    Чебоксары   37   Менеджер
# 9         Левина          NaN   56    Рабочий
# 10          Фикс         Рига   43    Рабочий

# %%
sample2['City'] = sample.City.apply(lambda x: str(x).lower())
sample2
# Out:
#             Name         City  Age Profession
# 0         Иванов       москва   26     Клинер
# 1            NaN    волгоград   32   Менеджер
# 2         Иванов       москва   26     Клинер
# 3        sidorov  владивосток   44   Менеджер
# 4        _______        курск   51   Водитель
# 5       Кузнецов         сочи   20    Рабочий
# 6          Сажин       сургут   30    Рабочий
# 7   Котлеревский   йошкар-ола   33    Рабочий
# 8     Завалишина    чебоксары   37   Менеджер
# 9         Левина          nan   56    Рабочий
# 10          Фикс         рига   43    Рабочий

# %%
def profession_code(s):
    if s == 'Рабочий':
        s=0
    elif s == 'Менеджер':
        s=1
    else:
        s=2
    return s

sample2 = sample

sample2['Profession'] = sample.Profession.apply(profession_code)
sample2
# Out:
#             Name         City  Age  Profession
# 0         Иванов       москва   26           2
# 1            NaN    волгоград   32           1
# 2         Иванов       москва   26           2
# 3        sidorov  владивосток   44           1
# 4        _______        курск   51           2
# 5       Кузнецов         сочи   20           0
# 6          Сажин       сургут   30           0
# 7   Котлеревский   йошкар-ола   33           0
# 8     Завалишина    чебоксары   37           1
# 9         Левина          nan   56           0
# 10          Фикс         рига   43           0

# %%
def age_category(s):
    if s < 23:
        s = 'молодой'
    elif 23 < s < 35:
        s ='средний'
    elif s > 35:
        s = 'зрелый'
    return s

sample['Age_category'] = sample.Age.apply(age_category)
sample
# Out:
#             Name         City  Age  Profession Age_category
# 0         Иванов       москва   26           2      средний
# 1            NaN    волгоград   32           1      средний
# 2         Иванов       москва   26           2      средний
# 3        sidorov  владивосток   44           1       зрелый
# 4        _______        курск   51           2       зрелый
# 5       Кузнецов         сочи   20           0      молодой
# 6          Сажин       сургут   30           0      средний
# 7   Котлеревский   йошкар-ола   33           0      средний
# 8     Завалишина    чебоксары   37           1       зрелый
# 9         Левина          nan   56           0       зрелый
# 10          Фикс         рига   43           0       зрелый

# %%
log = pd.read_csv('/Users/maryanapopova/Documents/GitHub/skillfactory/module_1/log.xls', header =None)
log
users = pd.read_csv('/Users/maryanapopova/Documents/GitHub/skillfactory/module_1/users.xls',
                    sep= '\t', encoding='koi8-r')
users
log
# Out:
#                                     0                     1        2        3
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN      NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN      NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN      NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN      NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN      NaN
# ..                                ...                   ...      ...      ...
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0      NaN
# 996                            #error                   NaN  10054.0  29265.0
# 997                            #error                   NaN  10454.0      NaN
# 998                            #error                   NaN   1000.0      NaN
# 999                            #error                   NaN  10754.0      NaN
#
# [1000 rows x 4 columns]

# %%
log.columns = ['user_id', 'time', 'bet', 'win']
def user_id_new(x):
    if x != '#error':
        x =x[x.find('-')+2:]
    else:
        x = ''
    return x
log['user_id'] = log.user_id.apply(user_id_new)
log
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-785fea559503> in <module>
# ----> 1 log.columns = ['user_id', 'time', 'bet', 'win']
#       2 def user_id_new(x):
#       3     if x != '#error':
#       4         x =x[x.find('-')+2:]
#       5     else:
#
# NameError: name 'log' is not defined

# %%
# Out:
# '2019-01-01 14:06:51'

# %%
import pandas as pd
log = pd.read_csv('/Users/evgeny/Documents/GitHub/skillfactory/module_1/log.xls', header =None)


log.columns = ['user_id', 'time', 'bet', 'win']

log1 = log

def data_1(x):
    if x != 'nan':
        x = str(x)[1:]
        print(x)
    
    
    
    
log1['time'] = log1.time.apply(data_1)
log1
# Out:
# 2019-01-01 14:06:51
# 2019-01-01 14:51:16
# 2019-01-01 16:31:16
# 2019-01-01 17:17:51
# 2019-01-01 21:31:18
# 2019-01-01 23:34:55
# 2019-01-01 4:37:25
# 2019-01-01 6:31:23
# 2019-01-02 10:57:08
# 2019-01-02 16:55:06
# 2019-01-02 20:47:54
# 2019-01-02 21:32:20
# 2019-01-02 21:32:35
# 2019-01-02 5:25:40
# 2019-01-02 8:57:36
# 2019-01-02 9:32:24
# 2019-01-03 10:43:41
# 2019-01-03 11:29:08
# 2019-01-03 13:12:46
# 2019-01-03 14:03:21
# 2019-01-03 17:20:23
# 2019-01-03 18:24:25
# 2019-01-03 18:45:54
# 2019-01-03 2:48:25
# 2019-01-03 5:30:43
# 2019-01-03 5:49:42
# 2019-01-04 1:59:34
# 2019-01-04 11:50:21
# 2019-01-04 12:49:31
# 2019-01-04 13:59:42
# 2019-01-04 15:07:26
# 2019-01-04 17:05:30
# 2019-01-04 18:21:37
# 2019-01-04 19:22:43
# 2019-01-04 2:59:24
# 2019-01-04 21:52:08
# 2019-01-04 23:16:33
# 2019-01-04 4:00:52
# 2019-01-04 5:40:14
# 2019-01-05 1:54:07
# 2019-01-05 10:44:56
# 2019-01-05 13:13:21
# 2019-01-05 14:36:15
# 2019-01-05 18:09:15
# 2019-01-05 20:55:29
# 2019-01-05 3:50:10
# ...
