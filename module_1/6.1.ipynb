# %%
import pandas as pd

df = pd.read_csv('/Users/evgeny/Documents/GitHub/skillfactory/module_1/data_sf.xls')
df
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
s = df['Club'].value_counts()

s.index
# Out:
# Index(['Shonan Bellmare', 'V-Varen Nagasaki', 'Padova', 'De Graafschap',
#        'FC Emmen', 'Vissel Kobe', 'Karlsruher SC', 'FC Carl Zeiss Jena',
#        'Lincoln City', 'Sagan Tosu',
#        ...
#        'Cagliari', 'América FC (Minas Gerais)', 'Cruzeiro', 'Olympiacos CFP',
#        'FC Metz', 'Dijon FCO', 'Dinamo Zagreb', 'GD Chaves',
#        'Vitória Guimarães', 'Atlético Mineiro'],
#       dtype='object', length=650)

# %%
s.index[0]
# Out:
# 'Shonan Bellmare'

# %%
len(s.index)

# %%
s = df['Position'].value_counts(normalize=True) < 0.01
display(s)
# Out:
# GK     False
# ST     False
# CB     False
# CM     False
# LB     False
# RB     False
# RM     False
# LM     False
# CDM    False
# CAM    False
# RCB    False
# LCB    False
# LW     False
# RCM    False
# RW     False
# LCM    False
# LDM    False
# RDM    False
# LS      True
# RS      True
# RWB     True
# LWB     True
# CF      True
# LF      True
# RF      True
# LAM     True
# RAM     True
# Name: Position, dtype: bool

# %%
s = df['Age'].value_counts()
display(s)
# Out:
# 21    1060
# 20     989
# 22     972
# 19     907
# 24     902
# 23     900
# 25     854
# 26     850
# 27     759
# 28     720
# 18     665
# 29     656
# 30     549
# 31     441
# 32     379
# 34     281
# 33     271
# 17     269
# 35     158
# 36     123
# 37      70
# 16      42
# 38      35
# 39      24
# 40      13
# 41       4
# 44       2
# 42       1
# 45       1
# Name: Age, dtype: int64

# %%
s = df['Wage'].value_counts()
display(s)
# Out:
# 1000      4601
# 2000      2652
# 3000      1596
# 4000       929
# 5000       566
#           ...
# 250000       1
# 185000       1
# 87000        1
# 300000       1
# 265000       1
# Name: Wage, Length: 142, dtype: int64

# %%
s = df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (435.999, 142000.0]     12818
# (142000.0, 283000.0]       61
# (283000.0, 424000.0]       16
# (424000.0, 565000.0]        2
# Name: Wage, dtype: int64

# %%
df[(df['Wage'] > s.index[3].left)&(df['Wage'] <= s.index[3].right)]
# Out:
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage  \
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000
#
#   Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0       RF        84         95  ...         75         96       33
# 7       RS        77         93  ...         85         85       62
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
# 7              45             38        27          25         31
#
#    GKPositioning  GKReflexes
# 0             14           8
# 7             33          37
#
# [2 rows x 42 columns]

# %%
s.index[3]
# Out:
# Interval(2.908, 21.2, closed='right')

# %%
# Out:
# <ipython-input-100-388fa0ce63b5>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(df['FKAccuracy'].value_counts(normalize=True) < 0.2)].value_counts(bins=5)
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-100-388fa0ce63b5> in <module>
# ----> 1 df[(df['FKAccuracy'].value_counts(normalize=True) < 0.2)].value_counts(bins=5)
#       2
#       3
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
# ...

# %%
s = df['FKAccuracy'].value_counts(bins=5)
display(s)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
s = df['FKAccuracy'].min()
display(s)
# Out:
# 3

# %%
result = df['Position'].nunique()
result
# Out:
# 27

# %%
result = len(df['Position'].value_counts())
result
# Out:
# 27

# %%
s = df['Nationality'].value_counts()
s_df = s.reset_index()
display(s_df)
# Out:
#            index  Nationality
# 0        England         1368
# 1        Germany          919
# 2          Spain          671
# 3         France          614
# 4      Argentina          574
# ..           ...          ...
# 151     Ethiopia            1
# 152     St Lucia            1
# 153     Botswana            1
# 154  Puerto Rico            1
# 155      Grenada            1
#
# [156 rows x 2 columns]

# %%
s_df.columns = ['Nationality','Players Count']
display(s_df)
# Out:
#      Nationality  Players Count
# 0        England           1368
# 1        Germany            919
# 2          Spain            671
# 3         France            614
# 4      Argentina            574
# ..           ...            ...
# 151     Ethiopia              1
# 152     St Lucia              1
# 153     Botswana              1
# 154  Puerto Rico              1
# 155      Grenada              1
#
# [156 rows x 2 columns]

# %%
s=df[df.Nationality == 'Spain']
sum(s.Wage. value_counts(bins=4))
result = sum(s.Wage. value_counts(bins=4))
t=s.Wage. value_counts(bins=4)
t.iloc[0]
result = t.iloc[0]/sum(s.Wage. value_counts(bins=4))*100
print(result)
# Out:
# 97.0193740685544

# %%
s = df[df.Club == 'Manchester United']
s.Nationality.nunique()
# Out:
# 13

# %%
s=df[(df.Nationality == 'Brazil') & (df.Club == 'Juventus')]
s.Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
s = df[df.Age > 35]
s.Club.value_counts()
# Out:
# Hokkaido Consadole Sapporo     4
# Club Atlético Huracán          4
# Club Atlético Colón            3
# Gimnasia y Esgrima La Plata    3
# Morecambe                      3
#                               ..
# Villarreal CF                  1
# Coventry City                  1
# KSV Cercle Brugge              1
# Scunthorpe United              1
# Real Betis                     1
# Name: Club, Length: 212, dtype: int64

# %%
s = len(df[(df.Nationality == 'Spain') & (df.Age == 21)])
t = len (df[df.Nationality == 'Spain'])
result = round(s/t*100,2)
result
# Out:
# 11.77

# %%
df.groupby(['Club']).groups
# Out:
# {' SSV Jahn Regensburg': [1642, 2284, 2374, 2401, 2575, 2583, 2850, 2868, 3418, 3908, 3989, 4154, 5151, 5177, 5525, 5885, 6070, 6679, 7173, 7477, 8905, 9061, 10825, 12482], '1. FC Heidenheim 1846': [1060, 1805, 1978, 2050, 2066, 2926, 3584, 3605, 4312, 4457, 4783, 6818, 7160, 7166, 7460, 9475, 10052, 10565, 11217, 12236], '1. FC Kaiserslautern': [2931, 3590, 4270, 4413, 4475, 4483, 4709, 4779, 5079, 5325, 5403, 5855, 5917, 7295, 8784, 9496, 9964, 10019, 10122, 10671, 11500, 11970, 12222], '1. FC Köln': [166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], '1. FC Magdeburg': [1967, 2069, 2152, 2569, 2886, 3030, 3300, 3332, 4436, 4913, 5002, 5033, 5493, 5768, 6329, 7046, 7595, 8387, 9626, 11125, 11400], '1. FC Nürnberg': [724, 1208, 1254, 1920, 4775, 5265, 5556, 5985, 8590, 8632, 9217, 9858, 10480], '1. FC Union Berlin': [1422, 1493, 2530, 2876, 3635, 3844, 4683, 4826, 11038, 11296, 12340], '1. FSV Mainz 05': [545, 670, 765, 1201, 1342, 6218, 6868, 8792, 10293, 10561, 10566], 'A
# ...

# %%
grouped_df = df.groupby(['Club']).sum()
display(grouped_df)
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum()
display(grouped_df)
# Out:
# Club
#  SSV Jahn Regensburg      90000
# 1. FC Heidenheim 1846     76000
# 1. FC Kaiserslautern      33000
# 1. FC Köln                92000
# 1. FC Magdeburg           84000
#                           ...
# Zagłębie Sosnowiec        27000
# Çaykur Rizespor          118000
# Örebro SK                 36000
# Östersunds FK             39000
# Śląsk Wrocław             50000
# Name: Wage, Length: 650, dtype: int64

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values()
print(grouped_df.head(5))
# Out:
# Club
# Dinamo Zagreb        7000
# Olympiacos CFP       8000
# PAOK                10000
# Shakhtar Donetsk    10000
# AEK Athens          11000
# Name: Wage, dtype: int64

# %%
grouped_df = df.groupby(['Position'])['Wage'].sum() > 5000000
grouped_df
# Out:
# Position
# CAM     True
# CB      True
# CDM    False
# CF     False
# CM      True
# GK      True
# LAM    False
# LB      True
# LCB    False
# LCM    False
# LDM    False
# LF     False
# LM      True
# LS     False
# LW     False
# LWB    False
# RAM    False
# RB      True
# RCB    False
# RCM    False
# RDM    False
# RF     False
# RM      True
# RS     False
# RW     False
# RWB    False
# ST      True
# Name: Wage, dtype: bool

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
df.groupby(['Nationality'])[['Wage','Value','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-278-124464058654> in <module>
# ----> 1 df.groupby(['Nationality'])[['Wage','Value','ShotPower']].sort_values(['Wage'],ascending=False).head(10)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_values'

# %%
df.groupby(['Position'])[['Wage', 'Value']].mean().sort_values(['Value'],ascending=False)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06
# LDM        10243.243243  3.369459e+06
# RCB        11270.334928  3.009055e+06
# CAM         8688.783570  2.963199e+06
# RDM        11282.608696  2.692717e+06
# LCB         9753.056235  2.636516e+06
# LM          7472.527473  2.466174e+06
# ST          7852.513228  2.157252e+06
# RM          6655.352480  2.138734e+06
# LWB         5783.333333  1.931333e+06
# CF          4862.745098  1.848627e+06
# CDM         7121.562952  1.658900e+06
# CM          5805.060918  1.617465e+06
# RWB         6000.000000  1.555571e+06
# ...

# %%
df.groupby(['Club'])['Wage'].agg(['mean','median']).sort_values(['mean'],ascending=False).head(100)
# Out:
#                             mean  median
# Club
# Real Madrid        188090.909091  207500
# FC Barcelona       180318.181818  145000
# Juventus           166785.714286  160000
# Manchester City    129041.666667  132500
# Manchester United  117850.000000  110000
# ...                          ...     ...
# Al Nassr            12826.086957    6000
# Getafe CF           12600.000000   17000
# SC Braga            12461.538462   13000
# RC Celta            12444.444444    8000
# Hannover 96         12363.636364    8000
#
# [100 rows x 2 columns]

# %%
n = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])
new_n = n[n['mean'] == n['median']].sort_values(['mean'],ascending = False)
display(new_n)
new_n.mean
# Out:
#                            mean  median
# Club
# Cruzeiro                13000.0   13000
# Göztepe SK               7000.0    7000
# Brøndby IF               6000.0    6000
# Sunderland               4000.0    4000
# CD Feirense              4000.0    4000
# 1. FC Magdeburg          4000.0    4000
# Northampton Town         2500.0    2500
# Stade Brestois 29        2000.0    2000
# Jeonnam Dragons          2000.0    2000
# Pohang Steelers          2000.0    2000
# AJ Auxerre               2000.0    2000
# Grimsby Town             2000.0    2000
# Heracles Almelo          2000.0    2000
# Philadelphia Union       2000.0    2000
# Kashiwa Reysol           2000.0    2000
# CD Tondela               2000.0    2000
# Benevento                2000.0    2000
# FC Metz                  1500.0    1500
# PAOK                     1000.0    1000
# Orlando Pirates          1000.0    1000
# Panathinaikos FC         1000.0    1000
# Patriotas Boyacá FC      1000.0    1000
# ...

# %%
n = df.groupby(['Club'])['Wage'].sum().sort_values(ascending = False)
n
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
#                       ...
# AEK Athens             11000
# Shakhtar Donetsk       10000
# PAOK                   10000
# Olympiacos CFP          8000
# Dinamo Zagreb           7000
# Name: Wage, Length: 650, dtype: int64

# %%
n = df[(df.Nationality == 'Argentina')&(df.Age == 30)]
n.Wage.min()
# Out:
# 1000

# %%
n = df[(df.Club == 'FC Barcelona') & (df.Nationality == 'Argentina')]['Balance']
n
# Out:
# 0    95
# Name: Balance, dtype: int64

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(
values =['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True)
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %%
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'count',fill_value=0)
round(df2['GK'].mean(),3)
# Out:
# 2.525

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
margins=True,
fill_value=0)
display(pivot)
# Out:
#                            Wage
# Club               FC Barcelona Juventus Manchester United Real Madrid All
# Nationality
# Argentina                     1        1                 2           0   4
# Belgium                       1        0                 1           1   3
# Bosnia Herzegovina            0        1                 0           0   1
# Brazil                        2        2                 1           2   7
# Chile                         1        0                 1           0   2
# Costa Rica                    0        0                 0           1   1
# Croatia                       1        1                 0           1   3
# Dominican Republic            0        0                 0           1   1
# Ecuador                       0        0                 1           0   1
# England                       0        0                 6           0   6
# France                        3        1                 2           3   9
# ...

# %%
pivot_position = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'count',fill_value=0)
round(pivot_position['GK'].mean(),3)
# Out:
# 2.525

# %%
pivot_position = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'count',fill_value=0)
cm_0 = pivot_position['CM'][pivot_position['CM'] == 0].value_counts()
cm_0
# Out:
# 0    136
# Name: CM, dtype: int64

# %%
rus = df.loc[df.Nationality == 'Russia'].pivot_table(columns = 'Club', index = 'Name', values = 'Wage')
rus
# Out:
# Club             AS Monaco  Cracovia  Dalkurd FF  FC Erzgebirge Aue  \
# Name
# A. Aliev               NaN       NaN      1000.0                NaN
# A. Golovin         61000.0       NaN         NaN                NaN
# A. Gordyushenko        NaN       NaN         NaN                NaN
# A. Kochenkov           NaN       NaN         NaN                NaN
# A. Lomovitskiy         NaN       NaN         NaN                NaN
# A. Makarov             NaN       NaN         NaN                NaN
# A. Miranchuk           NaN       NaN         NaN                NaN
# A. Mironov             NaN       NaN         NaN                NaN
# A. Tashaev             NaN       NaN         NaN                NaN
# A. Vasyutin            NaN       NaN         NaN                NaN
# D. Barinov             NaN       NaN         NaN                NaN
# D. Efremov             NaN       NaN         NaN                NaN
# D. Kombarov            NaN       NaN         NaN                NaN
# ...

# %%
speed = df.pivot_table(columns = 'Position', index = 'Club', 
                       values ='SprintSpeed', 
                       fill_value=0, 
                       aggfunc = 'mean').sort_values(['ST'])
speed
# Out:
# Position                     CAM    CB   CDM    CF    CM         GK  LAM  \
# Club
# Sporting de Charleroi   0.000000  49.0  59.0   0.0   0.0  33.400000    0
# Standard de Liège       0.000000   0.0  53.0   0.0  64.0  35.333333    0
# Stade Rennais FC       65.000000  53.0   0.0   0.0  54.0  40.000000    0
# PFC CSKA Moscow        69.000000  66.0  69.0  75.0  65.0  36.000000    0
# Málaga CF              65.000000  59.5  50.0   0.0  61.0  45.000000    0
# ...                          ...   ...   ...   ...   ...        ...  ...
# Leicester City         74.000000  57.0   0.0   0.0  57.0  60.000000    0
# Brøndby IF             74.000000  68.0  65.0   0.0  65.5  38.000000    0
# CD Lugo                72.000000  48.5  50.0   0.0  56.0  44.500000    0
# Sydney FC              79.500000  59.0   0.0   0.0  64.5  44.666667    0
# Vitória                70.666667  56.0  64.0   0.0   0.0  42.500000    0
#
# Position                      LB   LCB   LCM  ...         RB   RCB  RCM   RDM  \
# ...

# %%
operator_one = {
    1: 'pass',
    2: 'break',
    3: 'print',
    4: 'yield',
    5: 'try',
}

operator_two = {
    1: 'yield',
    2: 'global',
    3: 'pass',
    4: 'print',
    5: 'try',
}


def operator_important(operator_one, operator_two):
    """Поиск одинаковых элементов в словаре и словаре и запись в словарь."""

    operator_main = dict()
    all_keys = set(list(operator_one.keys()) + list(operator_two.keys()))

    for key in all_keys:
        # Если ключ есть в обоих словарях, и значение по ключу одинаковое
        if key in operator_one and key in operator_two and operator_one[key] == operator_two[key]:
            operator_main[key] = operator_one[key]

    return operator_main

d = operator_important(operator_one, operator_two)
print(d)  # {1: 'pass', 5: 'try'}
# Out:
# {5: 'try'}

# %%
import collections
list =('Найти количество символов в файле, используя' )
len(list)
# Out:
# 44
