# %%
import pandas as pd

data = pd.Series(["Январь", "Февраль", "Март", "Апрель"],
        index = ['Первый', "Второй", "Третий", "Четвёртый"])
display(data)

data.iloc[[0,3]]
# Out:
# Первый        Январь
# Второй       Февраль
# Третий          Март
# Четвёртый     Апрель
# dtype: object
# Первый       Январь
# Четвёртый    Апрель
# dtype: object

# %%
data = pd.Series(list(range(10, 1001)))

# %%
DataFrame = pd.DataFrame({'col1': [1, 10], 'col2': [3, 4]})
display(DataFrame)
# Out:
#    col1  col2
# 0     1     3
# 1    10     4

# %%
import pandas as pd
df = pd.DataFrame([ [1,2,3], [2,3,4] ],
             columns = ['foo', 'bar', 'baz'],
                index = ['foobar','foobaz'])
display(df)
# Out:
#         foo  bar  baz
# foobar    1    2    3
# foobaz    2    3    4

# %%
df = pd.DataFrame({'Тестовая колонка':[1,5]})
display(df)
# Out:
#    Тестовая колонка
# 0                 1
# 1                 5

# %%
football = pd.read_csv('/Users/evgeny/Documents/GitHub/skillfactory/module_1/data_sf.xls')
display(football.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
football = pd.read_csv('/Users/evgeny/Documents/GitHub/skillfactory/module_1/data_sf.xls')

football.Value.min()
# Out:
# 0

# %%
football = pd.read_csv('/Users/evgeny/Documents/GitHub/skillfactory/module_1/data_sf.xls')
football.describe(include = ['object'])
# Out:
#                 Name Nationality             Club Position
# count          12897       12897            12897    12897
# unique         12326         156              650       27
# top     J. Rodríguez     England  Shonan Bellmare       GK
# freq               9        1368               30     1641

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football.max())
# Out:
# Unnamed: 0                 13125
# Name               Óscar Whalley
# Age                           45
# Nationality             Zimbabwe
# Club               Śląsk Wrocław
# Value                  118500000
# Wage                      565000
# Position                      ST
# Crossing                      93
# Finishing                     95
# HeadingAccuracy               94
# ShortPassing                  93
# Volleys                       90
# Dribbling                     97
# Curve                         93
# FKAccuracy                    94
# LongPassing                   93
# BallControl                   96
# Acceleration                  97
# SprintSpeed                   96
# Agility                       96
# Reactions                     96
# Balance                       96
# ShotPower                     95
# Jumping                       95
# Stamina                       96
# Strength                      97
# LongShots                     94
# ...

# %%
football = pd.read_csv('/Users/evgeny/Documents/GitHub/skillfactory/module_1/data_sf.xls')

football[football.Age < 20]
# Out:
#        Unnamed: 0                Name  Age    Nationality  \
# 25             25           K. Mbappé   19         France
# 188           188          M. de Ligt   18    Netherlands
# 191           191       G. Donnarumma   19          Italy
# 285           285          K. Havertz   19        Germany
# 360           363          C. Pulisic   19  United States
# ...           ...                 ...  ...            ...
# 12892       13121        J. Lundstram   19        England
# 12893       13122  N. Christoffersson   19         Sweden
# 12894       13123           B. Worman   16        England
# 12895       13124      D. Walker-Rice   17        England
# 12896       13125           G. Nugent   16        England
#
#                       Club     Value    Wage Position  Crossing  Finishing  \
# 25     Paris Saint-Germain  81000000  100000       RM        77         88
# 188                   Ajax  27000000   11000      RCB        57         53
# ...

# %%
football[(football.Age < football.Age.mean())&
        (football.Club == 'FC Barcelona')]
# Out:
#       Unnamed: 0           Name  Age Nationality          Club     Value  \
# 42            42      S. Umtiti   24      France  FC Barcelona  57000000
# 141          141     O. Dembélé   21      France  FC Barcelona  40000000
# 190          190         Arthur   21      Brazil  FC Barcelona  32500000
# 195          195     C. Lenglet   23      France  FC Barcelona  26000000
# 235          235  Nélson Semedo   24    Portugal  FC Barcelona  20000000
# 1464        1515          Aleñá   20       Spain  FC Barcelona   6000000
# 5377        5539          Chumi   19       Spain  FC Barcelona   1000000
# 5613        5777   Jorge Cuenca   18       Spain  FC Barcelona    850000
# 6124        6293  Guillem Jaime   19       Spain  FC Barcelona    975000
# 7312        7493        Ezkieta   21       Spain  FC Barcelona    525000
# 9028        9226     Iñaki Peña   19       Spain  FC Barcelona    450000
#
#         Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# ...

# %%
#Какова средняя скорость (SprintSpeed) футболистов, зарплата (Wage) которых выше среднего? Ответ округлите до сотых.
speed_mean = football[football.Wage > football.Wage.mean()].SprintSpeed.mean()
round(speed_mean,2)
# Out:
# 67.57

# %%
#Какова средняя скорость (SprintSpeed) футболистов, зарплата (Wage) которых ниже среднего? Ответ округлите до сотых.
speed_mean = football[football.Wage < football.Wage.mean()].SprintSpeed.mean()
round(speed_mean,2)
# Out:
# 62.41

# %%
football = pd.read_csv('/Users/evgeny/Documents/GitHub/skillfactory/module_1/data_sf.xls')
football[football.Nationality == 'Brazil'].Penalties.sum()
# Out:
# 22789

# %%
football = pd.read_csv('/Users/evgeny/Documents/GitHub/skillfactory/module_1/data_sf.xls')
round(football[football.HeadingAccuracy > 50].Age.mean(),2)
# Out:
# 25.59

# %%
composure = football.Composure.max()
reactions = football.Reactions.max()
print(composure,reactions)
football[(football.Composure > composure*0.9) & (football.Reactions > reactions*0.9)].Age.min()
# Out:
# 96 96
# 24

# %%
result = round(football[football.Age == football.Age.max()].Reactions.mean()
               -football[football.Age == football.Age.min()].Reactions.mean(),2)
result
# Out:
# 22.64

# %%
country = football[football.Value > football.Value.mean()].Nationality
nation = {}
result ={}
for i in country:
    if i in nation:
        nation[i]+=1
    else:
        nation[i] = 1
nation = pd.Series(nation)
print(nation.idxmax(),nation.max())
# Out:
# Spain 211

# %%
wage_gk_ref = football[(football.GKReflexes == football.GKReflexes.max()) 
                   & (football.Position == 'GK')].Wage.mean()
wage_gk_hand = football[football.GKHandling == football.GKHandling.max()].Wage.mean()
round(wage_gk_ref/wage_gk_hand,2)
# Out:
# 2.77

# %%
round((football[football.Aggression == football.Aggression.max()].ShotPower.mean() 
       / football[football.Aggression == football.Aggression.min()].ShotPower.mean()),2)
# Out:
# 2.08

# %%
import numpy as np

ndarr = np.array([1, 2, 3, 4, 5, ])
numpy.ndarray
s3 = pd.Series(ndarr,['a', 'b', 'c', 'd', 'e'])
print(s3)
d = {'a':1, 'b':2, 'c':3}
s4 = pd.Series(d)
print(s4)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
d = {"price":pd.Series([1, 2, 3], index=['v1', 'v2', 'v3']),
     "count": pd.Series([10, 12, 7], index=['v1', 'v2', 'v3'])}
df1 = pd.DataFrame(d)

display(df1)


print(df1.index)


print(df1.columns)
# Out:
#     price  count
# v1      1     10
# v2      2     12
# v3      3      7
# Index(['v1', 'v2', 'v3'], dtype='object')
# Index(['price', 'count'], dtype='object')

# %%
football[['Age','Name']]
# Out:
#        Age                Name
# 0       31            L. Messi
# 1       33   Cristiano Ronaldo
# 2       26           Neymar Jr
# 3       27              De Gea
# 4       27        K. De Bruyne
# ...    ...                 ...
# 12892   19        J. Lundstram
# 12893   19  N. Christoffersson
# 12894   16           B. Worman
# 12895   17      D. Walker-Rice
# 12896   16           G. Nugent
#
# [12897 rows x 2 columns]

# %%
football.sample(n=2, axis=1)
# Out:
#        SlidingTackle  GKReflexes
# 0                 26           8
# 1                 23          11
# 2                 33          11
# 3                 13          94
# 4                 51          13
# ...              ...         ...
# 12892             47           9
# 12893             19          12
# 12894             11          13
# 12895             27           9
# 12896             50           9
#
# [12897 rows x 2 columns]

# %%
# %time sum([x for x in range(100000)])
# Out:
# CPU times: user 3.79 ms, sys: 251 µs, total: 4.04 ms
# Wall time: 4.05 ms
# 4999950000

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
# Out:
#     bar  baz foobar
# 0   1.2    2     hi
# 1   2.2    3     hi
# 2   3.2    4     hi
# 3   4.2    5     hi
# 4   5.2    6     hi
# 5   6.2    7     hi
# 6   7.2    8     hi
# 7   8.2    9     hi
# 8   9.2   10     hi
# 9  10.2   11     hi
